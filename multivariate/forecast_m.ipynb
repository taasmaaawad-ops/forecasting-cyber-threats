# %%
# access to content
# %cd /content

#  delete previous copy
# !rm -rf forecasting-cyber-threats

# new clone
# !git clone -v https://github.com/taasmaaawad-ops/forecasting-cyber-threats.git

# access to folder
# !ls forecasting-cyber-threats/
# Out:
# /content
# Cloning into 'forecasting-cyber-threats'...
# POST git-upload-pack (175 bytes)
# POST git-upload-pack (202 bytes)
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (344/344), done.
# remote: Compressing objects: 100% (341/341), done.
# remote: Total 344 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (344/344), 28.91 MiB | 16.47 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# multivariate  README.md  univariate

# %%
import csv
from pandas import read_csv
from matplotlib import pyplot as plt
import numpy as np
import os
import sys
import seaborn as sns
import pandas as pd
import math
from numpy import split
import random

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

from scipy.optimize import minimize
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import numpy
from tqdm import tqdm_notebook
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from numpy import array
#from itertools import product
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from tensorflow.keras import optimizers
from tensorflow import keras
import tensorflow as tf
from numpy.random import seed
from scipy import stats
from IPython.display import clear_output
import statistics
import keras.backend as K

plt.rcParams['savefig.dpi'] = 300

#for parsing the units, this function removes the comma and replaces it with dash to avoid splitting the units (as different hyperparameters) when building the hyperparameters list
def removeCommaInUnits(HP):
  units= HP[HP.index('['):HP.index(']')+1]
  if ',' in units:
    units = units.replace(',','-')
  HP=HP.replace(HP[HP.index('['):HP.index(']')+1],units)
  return HP

#this function puts back the comma in its place as it is needed while building our model
def putCommaInUnitsList(HP):
  return [i.replace('-',',') for i in HP]


def maximum(a, b):

    if a >= b:
        return a
    else:
        return b

def minimum(a, b):

    if a <= b:
        return a
    else:
        return b


def exponential_smoothing(series, alpha):

    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):

    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing - "+attack)
    plt.grid(True);

def double_exponential_smoothing(series, alpha, beta):

    result = [series[0]]
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):

    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing - "+attack)
    plt.grid(True)
    plt.show()


#stationarity test
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):

    if not isinstance(y, pd.Series):
        y = pd.Series(y)

    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))

        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title(attack_title+' - Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        plt.show()


# convert history into inputs and outputs
def to_supervised(train, n_input, n_out=1):
    # flatten data
    data = train #modified

    X, y = list(), list()
    in_start = 0
    # step over the entire history one time step at a time
    for _ in range(len(data)):
        # define the end of the input sequence
        in_end = in_start + n_input
        out_end = in_end + n_out
        # ensure we have enough data for this instance
        if out_end <= len(data):
            X.append(data[in_start:in_end, :])
            y.append(data[in_end:out_end, :])
        # move along one time step
        in_start += 1
    return array(X), array(y)

#Bayesian LSTM

# class BayesianLSTM(LSTM): #inherits LSTM but set training=True which keeps dropout on during test time.
#   def call(self, inputs):
#     return super().call(inputs, training=True)


class BayesianLSTM(tf.keras.layers.Layer):
    def __init__(self, units, return_sequences=False, recurrent_dropout=0.0, **kwargs):
        super().__init__()
        self.units = units
        self.return_sequences = return_sequences
        self.recurrent_dropout = recurrent_dropout

        self.lstm = tf.keras.layers.LSTM(
            units,
            return_sequences=return_sequences,
            **kwargs
        )
        self.dropout_layer = tf.keras.layers.Dropout(recurrent_dropout)

    def call(self, inputs, training=None):
        # training=True دايماً عشان يفضل dropout شغال وقت الـ prediction
        x = self.dropout_layer(inputs, training=True)
        return self.lstm(x, training=True)

    def build(self, input_shape):
        self.lstm.build(input_shape)
        self.built = True




# train the model using Bayesian LSTM
def build_model(train, test, n_input, layer, unit, epoch, lr,rdo,n_features):

    # prepare data
    train_x, train_y = to_supervised(train, n_input)
    test_x, test_y=to_supervised(test,n_input)


    # define parameters
    verbose, epochs, batch_size = 0,epoch, 8


    model = Sequential()


    if layer==1:
        model.add(BayesianLSTM(unit[0], input_shape=(n_input, n_features),recurrent_dropout=rdo, activation = keras.layers.LeakyReLU(alpha=0.2)))
        model.add(RepeatVector(1))
        model.add(BayesianLSTM(unit[0], activation = keras.layers.LeakyReLU(alpha=0.2), return_sequences=True, recurrent_dropout=rdo))
        model.add(TimeDistributed(Dense(100, activation = keras.layers.LeakyReLU(alpha=0.2))))
        model.add(TimeDistributed(Dense(n_features)))
    elif layer==2:
        model.add(BayesianLSTM(unit[0], activation = keras.layers.LeakyReLU(alpha=0.2), input_shape=(n_input, n_features),return_sequences=True,recurrent_dropout=rdo))
        model.add(BayesianLSTM(unit[1], activation = keras.layers.LeakyReLU(alpha=0.2) ,recurrent_dropout=rdo))
        model.add(RepeatVector(1))
        model.add(BayesianLSTM(unit[1], activation = keras.layers.LeakyReLU(alpha=0.2), return_sequences=True,recurrent_dropout=rdo))
        model.add(BayesianLSTM(unit[0], activation = keras.layers.LeakyReLU(alpha=0.2), return_sequences=True,recurrent_dropout=rdo))
        model.add(TimeDistributed(Dense(100, activation = keras.layers.LeakyReLU(alpha=0.2))))
        model.add(TimeDistributed(Dense(n_features)))

    opt = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=opt, loss='mse', metrics=['mape']) #compile the model with mean square error as the loss function

    #if the loss does not improve after 30 epochs, stop anyway (early stopping)
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

    # fit network
    train_history= model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(test_x, test_y),verbose=verbose,callbacks=[es])

    loss = train_history.history['loss']
    val_loss = train_history.history['val_loss']

    return model


#forecasts the future trend of a single attack 3 years in advance
def forecast(data, e_data, smoothed, model, min_list,seed, attack_label):

    #get best model's hyperparameters
    n_input=min_list[2]
    layer=min_list[3]
    unit=min_list[4]
    lr=min_list[5]
    epoch=min_list[6]
    rdo=min_list[7]
    n_features=min_list[9]

    #build the model using the best hyperparameters using the whole data
    model = build_model(e_data, e_data, n_input, layer, unit, epoch, lr,rdo,n_features)

    #Bayesian LSTM performs multiple iterations to create a prediction distribution (i.e., mean and variance)
    n_iterations=10
    predictions_2d=list()
    for r in range(0,n_iterations):

      predictions = list()
      predictions.append(e_data[-1,]) #for plotting purpose
      #look back in test data
      history=e_data[-n_input:,]

      for i in range(36): #predicts 36 months using sliding-window
        f_hat=model.predict(history.reshape(1,history.shape[0],history.shape[1]))
        history=numpy.append(history, f_hat[0][0])
        history=history.reshape(-1,n_features)
        history=history[1:,]#move the sliding window 1 step
        predictions.append(f_hat[0][0])
      predictions_2d.append(predictions)


    predictions_2d = array(predictions_2d)
    predictions_mean=numpy.mean(predictions_2d,axis=0)#mean
    predictions_var=numpy.var(predictions_2d,axis=0)#variance
    std_predictions=numpy.std(predictions_2d,axis=0)#standard deviation
    z=1.96
    confidence_95=z*std_predictions/math.sqrt(len(predictions_mean))# 95% confidence interval

    #get only first feature (ground truth prediction)
    data= data[:,0]
    predictions_mean=predictions_mean[:,0]
    confidence_95=confidence_95[:,0]
    predictions_var=predictions_var[:,0]

    #calculate the height of data on the plot (plot range) to disable variance/95% conf.interval plot if too large or too small.
    upper=maximum(numpy.amax(predictions_mean),numpy.amax(data))
    lower=minimum(numpy.amin(predictions_mean),numpy.amin(data))
    p_range=upper-lower
    var_plot=True
    max_var=0
    for v in predictions_var:
      if v>p_range:
        var_plot=False
      if v>max_var:
        max_var=v
    if max_var*30<p_range:
      var_plot=False

    conf_plot=True
    max_conf=0
    for conf in confidence_95:
      if conf>p_range:
        conf_plot=False
      if conf>max_conf:
        max_conf=conf
    if max_conf*30<p_range:
      conf_plot=False


    print(e_data)
    print(predictions_mean)

    #Plot the forecast
    x=['2012', '2013','2014', '2015', '2016', '2017', '2018','2019', '2020', '2021','2022','2023','2024','2025']
    pyplot.plot(range(len(data)),data,'--', color="blue",label='Data')
    pyplot.plot(range(len(data), len(data)+len(predictions_mean)),predictions_mean,'--', color="red",label='Prediction')
    if conf_plot:
      pyplot.fill_between(range(len(data), len(data)+len(predictions_mean)),(predictions_mean.reshape(-1)- (confidence_95.reshape(-1))), (predictions_mean.reshape(-1)+confidence_95.reshape(-1)), color='green', alpha=0.2,label='95% Confidence')
    if var_plot:
      pyplot.fill_between(range(len(data), len(data)+len(predictions_mean)),(predictions_mean.reshape(-1)- (predictions_var.reshape(-1))), (predictions_mean.reshape(-1)+predictions_var.reshape(-1)), color='green', alpha=0.1,label='Variance')
    plt.xticks([6,18,30,42,54,66,78,90,102,114,126,138,150,162], x) # positions of years on x axis
    plt.ylabel("No of incidents",fontsize=15)
    plt.yticks(fontsize=13)
    plt.legend(loc="best",prop={'size': 11})
    plt.axis('tight')
    plt.grid(True)
    pyplot.xticks(rotation=90,fontsize=13)
    pyplot.title(attack_label+' (M)', y=1.03,fontsize=18)

    #save the forecast plot to file
    images_dir = '/content/forecasting-cyber-threats/multivariate/output_forecast/'
    plt.savefig(f"{images_dir}/"+attack_label.replace('/','_')+str(seed)+".png",bbox_inches = "tight")#the name of the file includes the seed
    pyplot.show()

    #write the data and forecast
    data=data.ravel().tolist()
    predictions_mean=predictions_mean.tolist()

    files_dir = '/content/forecasting-cyber-threats/multivariate/output_forecast/'
    with open(files_dir+attack_title.replace('/','_')+'_data_'+str(seed)+'.txt', 'w') as f: #the name of the file includes the seed
      f.write('Data: '+str(data))
      f.write('\nPredictions: '+str(predictions_mean))
      data.extend(predictions_mean)
      f.write('\nData and Predictions: '+str(data))
      f.write('\n95_Confidence: '+str(confidence_95.tolist()))
      f.write('\nVariance: '+str(predictions_var.tolist()))
      f.close()



#read input data
data = read_csv('/content/forecasting-cyber-threats/multivariate/input_data/T-HMGDN-F-0711-0322.csv', header=0)
attacks=data.columns.values.tolist()
raw_values = data.values
avg_data=0
scaler = MinMaxScaler(feature_range=(0, 1))

#name of attack columns (in the dataset) to be forecasted. "All" refers to the number of attacks in all countries combined
attacks=['Phishing-ALL', 'Password Attack-ALL', 'SQL Injection-ALL',
         'Defacement-ALL', 'Trojan-ALL', 'Vulnerability-ALL', 'Advanced persistent threat-ALL',
         'XSS-ALL', 'Data Breach-ALL', 'Disinformation/Misinformation-ALL', 'Targeted Attack-ALL','Adware-ALL',
         'Malvertising-ALL', 'Backdoor-ALL', 'Cryptojacking-ALL','Worms-ALL', 'Spyware-ALL',  'Mentions-DNS Spoofing',
         'Mentions-WannaCry Ransomware','Mentions-Wiper', 'Mentions-Pharming', 'Mentions-Insider Threat',
         'Mentions-Drive-by', 'Mentions-Rootkit', 'Mentions-Data Poisoning', 'Mentions-Keylogger', 'Mentions-DNS Tunneling',
         'Mentions-Session Hijacking','Mentions-URL manipulation']

done=[] #can be manually appended with already forecasted attacks to avoid repeating the process



#iterate over all attacks to forecast their trend
for attack in attacks:
  if attack in done:
    continue
  clear_output()

  if not 'ALL' in attack and not 'Mentions' in attack:
    continue;
  if 'Mentions-' in attack:
    attack_title=attack[attack.index('-')+1:]
  else:
    attack_title=attack[0:attack.rindex('-')]


  if len(attack_title)>18:
    attack_title=attack_title.rsplit(' ', 1)[0]



  # get the optimal model hyperparameters from file
  files_dir = '/content/forecasting-cyber-threats/multivariate/output_hyperparameters/'
  with open(f"{files_dir}/"+attack_title.replace('/','_')+'.txt') as f:
      lines = f.readlines()
      f.close()
  HP_str= lines[1]
  HP_str=HP_str[HP_str.index('[')+1:-1]
  HP_str=removeCommaInUnits(HP_str)
  HP=HP_str.split(', ')
  HP=putCommaInUnitsList(HP)
  print('HP:',HP)


  min_mape=999999999
  min_list=[]
  model=None
  c=1

  best_data=[]
  n_features=2 #number of features by default (Hackmageddon ground truth + 1 more)
  features=[1,2,3,4] # 1- attack mentions 2- Armed Conflict Areas/Wars 3- Holidays 4- Mix of all features. Ground truth Hackmageddon is always there as the first feature.

  #get smoothing constants
  alpha=float(HP[0])
  beta=float(HP[1])

  #get feature combination number
  feature=int(HP[10])
  print('features=',feature)

  #number of features is 2 unless the number of combination is the 4th, the case in which all features combined.
  if feature==4:
    n_features=4 #update the number of features since all features combined

  #building attack title for plots
  rest=attack[:-4]
  if 'Mentions-' in attack:
   rest=attack[9:]

  featureList=[] #to be used as the input data to the model later

  #if alpha and beta <1 then the method is double exponential smoothing
  # if alpha<1 and beta = 1, the method is exponential smoothing
  # if both beta and alpha equal 1, then no smoothing

  #Double Exponential Smoothing
  if not alpha==1 and not beta==1:
    smoothed=double_exponential_smoothing(data[attack], alpha,beta)
    smoothed=smoothed[0:-1]  #remove the one future step forecast from des
    plt.plot(data[attack], label = "Actual")
    plt.plot(smoothed, label="Alpha {}, beta {}".format(alpha, beta),color="red")
    plt.title("Double Exponential Smoothing - "+attack_title)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.grid(True)
    plt.xlabel("Month")
    if 'Mentions-' in attack:
     plt.ylabel("No of mentions")
    else:
     plt.ylabel("No of incidents")
    plt.show() #plot the data and smoothed data
    avg_data=sum(smoothed)/len(smoothed)
    featureList.append(smoothed)

    #smooth and plot the other features if included in this random selection
    #1- attack mentions 2- Armed Conflict Areas/Wars 3- Holidays 4- Mix of all features. Ground truth Hackmageddon is always there as the first feature.
    if feature==1 or feature==4:
        smoothed_v=double_exponential_smoothing(data['Mentions-'+rest], alpha,beta)
        smoothed_v=smoothed_v[0:-1] #thanks for the one additional forecast but no thanks,
        plt.plot(data['Mentions-'+rest], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}, beta {}".format(alpha, beta),color="red")
        plt.title("Double Exponential Smoothing - "+'Mentions of '+rest)
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)

    if feature==2 or feature==4:
        smoothed_v=double_exponential_smoothing(data['WAR/CONFLICT ALL'], alpha,beta)
        smoothed_v=smoothed_v[0:-1] #remove the one future step forecast from des
        plt.plot(data['WAR/CONFLICT ALL'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}, beta {}".format(alpha, beta),color="red")
        plt.title("Double Exponential Smoothing - "+'WAR/CONFLICT')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)

    if feature==3 or feature==4:
        smoothed_v=double_exponential_smoothing(data['Holidays'], alpha,beta)
        smoothed_v=smoothed_v[0:-1] #remove the one future step forecast from des
        plt.plot(data['Holidays'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}, beta {}".format(alpha, beta),color="red")
        plt.title("Double Exponential Smoothing - "+'Holidays')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of holidays")
        plt.show()
        featureList.append(smoothed_v)


  #exponential smoothing
  elif beta==1 and not alpha==1:
    smoothed=exponential_smoothing(data[attack], alpha)
    plt.plot(data[attack], label = "Actual")
    plt.plot(smoothed, label="Alpha {}".format(alpha),color="red")
    plt.title("Exponential Smoothing - "+attack_title)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.grid(True)
    plt.xlabel("Month")
    if 'Mentions-' in attack:
        plt.ylabel("No of mentions")
    else:
        plt.ylabel("No of incidents")
    plt.show()
    avg_data=sum(smoothed)/len(smoothed)
    featureList.append(smoothed)

    if feature==1 or feature==4:
        smoothed_v=exponential_smoothing(data['Mentions-'+rest], alpha)
        plt.plot(data['Mentions-'+rest], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}".format(alpha),color="red")
        plt.title("Exponential Smoothing - "+'Mentions of '+rest)
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)

    if feature==2 or feature==4:
        smoothed_v=exponential_smoothing(data['WAR/CONFLICT ALL'], alpha)
        plt.plot(data['WAR/CONFLICT ALL'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}".format(alpha),color="red")
        plt.title("Exponential Smoothing - "+'WAR/CONFLICT')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)
    if feature==3 or feature==4:
        smoothed_v=exponential_smoothing(data['Holidays'], alpha)
        plt.plot(data['Holidays'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}".format(alpha),color="red")
        plt.title("Exponential Smoothing - "+'Holidays')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of holidays")
        plt.show()
        featureList.append(smoothed_v)


  #no smoothing
  elif alpha==1 and beta==1:
    smoothed=data[attack]
    avg_data=smoothed.mean()
    featureList.append(smoothed)
    if feature==1 or feature==4:
        smoothed_v=data['Mentions-'+rest]
        featureList.append(smoothed_v)
    if feature==2 or feature==4:
        smoothed_v=data['WAR/CONFLICT ALL']
        featureList.append(smoothed_v)
    if feature==3 or feature==4:
        smoothed_v=data['Holidays']
        featureList.append(smoothed_v)



  #stationarity test
  tsplot(smoothed, lags=30)


  smoothed_all=numpy.array([smoothed]).reshape(-1,1)

  ##################################normalization##############################################
  featureList=numpy.transpose(featureList)
  prepared_data=numpy.array(featureList).reshape(-1,n_features)
  scaled_data = scaler.fit_transform(prepared_data)
  print('data shape=',scaled_data.shape)
  ##################################normalization##############################################

  #cut first part of the data if it is zeros (look for emerging index of the attack)
  e_index=0 #emerging index
  for i in range(len(scaled_data[:,0])-2):
    if scaled_data[i,0]>0 and scaled_data[i+1,0]>0 and scaled_data[i+2,0]>0:
        e_index=i
        break
  print('Emerging Index=',e_index)
  scaled_e_data=scaled_data[e_index:]
  print('Length of data after cut=',len(scaled_e_data))

  #Get model hyperparameters:
  lag=int(HP[2])#lookback period
  lr=float(HP[5])#learning rate
  epoch=int(HP[6])# epochs
  unit=list(map(int, HP[4].replace('[','').replace(']','').split(', '))) #units
  layer=len(unit) #layers
  rdo=float(HP[7]) #recurrent dropout
  diff_label='not differenced' #no differencing

  #build the set of hyperparameters based on the optimised model
  hp_set=[alpha, beta,lag,layer, unit, lr, epoch,rdo,diff_label,n_features, feature]
  print('Hyperparameters:',hp_set)

  #forecast the attack's future trend using 3 seeds 1-3
  for a in range(1,4):
   print('seed:',a)
   seed(a)
   tf.random.set_seed(a)
   forecast(scaled_data,scaled_e_data,smoothed_all, model,hp_set,a, attack_title)
# Out:
# HP: ['0.05', '0.7', '3', '2', '[64, 28]', '0.01', '50', '0.3', "'not differenced'", '4', '4', '2']
# features= 4
# data shape= (129, 4)
# Emerging Index= 0
# Length of data after cut= 129
# Hyperparameters: [0.05, 0.7, 3, 2, [64, 28], 0.01, 50, 0.3, 'not differenced', 4, 4]
# seed: 1
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# [[1.06961492e-01 5.79654627e-01 0.00000000e+00 1.88603304e-01]
#  [9.20376627e-02 3.60522337e-01 2.43250387e-02 4.45253200e-01]
#  [1.07409207e-01 2.61539286e-01 3.54364849e-02 5.62670527e-01]
#  [1.28339132e-01 1.71517624e-01 4.54877974e-02 6.71390631e-01]
#  [1.51503778e-01 1.05772599e-01 5.99691352e-02 7.68496081e-01]
#  [1.75047906e-01 4.53209285e-02 7.16949233e-02 8.62378480e-01]
#  [2.12044969e-01 1.90691205e-02 8.10480234e-02 9.47761767e-01]
#  [2.43290400e-01 3.28542921e-04 9.02613778e-02 9.82113036e-01]
#  [2.71410671e-01 0.00000000e+00 9.61111616e-02 9.89578142e-01]
#  [2.90727585e-01 3.87016464e-02 9.82398443e-02 1.00000000e+00]
#  [3.12981593e-01 7.99089519e-02 9.99598618e-02 9.92296274e-01]
#  [3.32396705e-01 1.28466488e-01 9.92274737e-02 9.47714763e-01]
#  [3.68731744e-01 1.86054888e-01 9.57284942e-02 8.74151083e-01]
#  [3.85730728e-01 2.58299971e-01 9.11733209e-02 7.95934607e-01]
#  [4.01263686e-01 3.28070245e-01 8.58640175e-02 6.99919448e-01]
#  [4.23665324e-01 3.98911771e-01 8.08162027e-02 6.10548378e-01]
#  [4.50166530e-01 4.68129673e-01 7.70740147e-02 5.07707403e-01]
#  [4.46839667e-01 5.35586280e-01 6.88996066e-02 4.24127396e-01]
#  [4.31559554e-01 6.02083998e-01 6.23569751e-02 3.46484844e-01]
#  [4.05570586e-01 6.53415581e-01 5.40306060e-02 2.61763627e-01]
#  [3.68788127e-01 7.02275853e-01 5.02957437e-02 1.93097802e-01]
#  [3.27964101e-01 7.33121035e-01 4.68755858e-02 1.28727011e-01]
#  [3.03421524e-01 7.52819396e-01 4.31201127e-02 9.70338391e-02]
#  [2.63231009e-01 7.67227621e-01 3.70195475e-02 5.57880565e-02]
#  [2.21147589e-01 7.74960464e-01 3.41335582e-02 1.74788336e-02]
#  [1.73664727e-01 7.71163018e-01 4.66808338e-02 3.11504684e-03]
#  [1.21893484e-01 7.60105610e-01 6.28776674e-02 0.00000000e+00]
#  [7.45386862e-02 7.43447147e-01 6.88562016e-02 1.36813612e-02]
#  [3.99392013e-02 7.11617042e-01 7.27526482e-02 3.44238555e-02]
#  [3.71737942e-02 6.75987815e-01 7.36284610e-02 8.05858943e-02]
#  [1.69539854e-02 6.37747430e-01 7.33488015e-02 1.44978169e-01]
#  [0.00000000e+00 5.99024747e-01 7.22905483e-02 1.91901290e-01]
#  [1.12170172e-02 5.51612135e-01 7.99598864e-02 2.39231265e-01]
#  [1.36955816e-02 5.08933668e-01 8.42481501e-02 3.10201340e-01]
#  [1.56581864e-02 4.66182896e-01 8.65351506e-02 3.82840380e-01]
#  [1.90393459e-02 4.37659029e-01 8.82775150e-02 4.44218833e-01]
#  [2.46571501e-02 4.15020722e-01 9.84981782e-02 4.94147959e-01]
#  [5.72005587e-02 3.89515169e-01 1.09722563e-01 5.30999794e-01]
#  [7.76955082e-02 3.75475774e-01 1.16875213e-01 5.57686195e-01]
#  [9.61753027e-02 3.79382124e-01 1.22053955e-01 5.95483423e-01]
#  [1.12952027e-01 3.96390297e-01 1.24467974e-01 6.07487872e-01]
#  [1.55170045e-01 4.16770991e-01 1.27851245e-01 6.29216762e-01]
#  [1.84374397e-01 4.67880437e-01 1.28592172e-01 6.45949238e-01]
#  [2.10491058e-01 5.00873616e-01 1.26863640e-01 6.37836545e-01]
#  [2.32237995e-01 5.40701792e-01 1.26746982e-01 6.12972103e-01]
#  [2.50453005e-01 5.83126640e-01 1.23175679e-01 6.04956279e-01]
#  [2.55422385e-01 6.13808842e-01 1.18136455e-01 5.98167886e-01]
#  [2.52857828e-01 6.35212469e-01 1.12792386e-01 5.64061003e-01]
#  [2.73036142e-01 6.82860531e-01 1.09995975e-01 5.25916001e-01]
#  [2.72476456e-01 7.40239215e-01 1.09516065e-01 4.76853253e-01]
#  [2.88612094e-01 7.99549739e-01 1.13864964e-01 4.38573299e-01]
#  [2.83517470e-01 8.53054180e-01 1.15735470e-01 3.94741642e-01]
#  [2.78579578e-01 8.92658472e-01 1.18467227e-01 3.45282844e-01]
#  [2.68329663e-01 9.48113429e-01 1.16908682e-01 3.21648573e-01]
#  [2.54511360e-01 9.75062911e-01 1.18570954e-01 3.03144751e-01]
#  [2.61888714e-01 9.88992049e-01 1.31045536e-01 2.74574783e-01]
#  [2.48961323e-01 1.00000000e+00 1.34907640e-01 2.63786281e-01]
#  [2.31859545e-01 9.91786143e-01 1.34885894e-01 2.43244046e-01]
#  [2.11763759e-01 9.79655892e-01 1.34537559e-01 2.54237417e-01]
#  [1.88258491e-01 9.50309745e-01 1.30014529e-01 2.48570123e-01]
#  [1.63717355e-01 9.16617128e-01 1.32289985e-01 2.46824235e-01]
#  [1.61511447e-01 8.83087280e-01 1.34250863e-01 2.42863710e-01]
#  [1.45604831e-01 8.40165556e-01 1.37640975e-01 2.49845879e-01]
#  [1.47683888e-01 8.19543628e-01 1.43260770e-01 2.66073408e-01]
#  [1.35399215e-01 7.84808403e-01 1.41889853e-01 2.74022535e-01]
#  [1.20942595e-01 7.70527009e-01 1.39542683e-01 3.09986402e-01]
#  [1.03772011e-01 7.63588948e-01 1.52035636e-01 3.60473402e-01]
#  [1.11113930e-01 7.41595586e-01 1.54149592e-01 3.78529512e-01]
#  [1.01825682e-01 7.10713566e-01 1.55862041e-01 3.92507722e-01]
#  [9.22488599e-02 6.80112921e-01 2.05868301e-01 4.29108671e-01]
#  [8.23599860e-02 6.55071391e-01 2.20044897e-01 4.64444630e-01]
#  [7.25207734e-02 6.40868936e-01 2.28795631e-01 4.95492703e-01]
#  [6.18045859e-02 6.51778992e-01 2.35141656e-01 5.01565719e-01]
#  [7.54785155e-02 6.49135705e-01 2.61413383e-01 5.03326044e-01]
#  [7.35648454e-02 6.56307273e-01 2.72630983e-01 5.06777808e-01]
#  [7.23560978e-02 7.25766234e-01 2.76905361e-01 5.07979109e-01]
#  [7.11131413e-02 7.55661004e-01 2.88384448e-01 4.94960523e-01]
#  [6.92469271e-02 7.74763236e-01 2.98237127e-01 4.97761810e-01]
#  [1.36361673e-01 7.83940035e-01 3.16778472e-01 4.98434260e-01]
#  [1.80959222e-01 8.05964502e-01 3.39835515e-01 4.82001470e-01]
#  [2.04358069e-01 8.32886781e-01 3.77460397e-01 4.64575733e-01]
#  [2.68285370e-01 8.46860666e-01 5.06301258e-01 4.54440609e-01]
#  [2.93932716e-01 8.72522566e-01 5.85579867e-01 4.56455097e-01]
#  [3.11828320e-01 8.92116849e-01 6.58440465e-01 4.44276218e-01]
#  [3.44081860e-01 9.03405942e-01 7.32648442e-01 4.15605323e-01]
#  [3.50305774e-01 9.05326777e-01 7.81992644e-01 3.96350292e-01]
#  [3.70870688e-01 9.06186729e-01 8.35829721e-01 3.79580902e-01]
#  [3.65687061e-01 9.00991115e-01 8.56908158e-01 3.55003148e-01]
#  [3.74503370e-01 8.86688559e-01 8.72491416e-01 3.32737189e-01]
#  [3.80230622e-01 9.01898361e-01 8.71733287e-01 3.32091604e-01]
#  [4.07409825e-01 9.01632750e-01 8.41179282e-01 3.34155705e-01]
#  [4.16744844e-01 8.94369324e-01 8.31399547e-01 3.22869857e-01]
#  [4.46707690e-01 8.80562785e-01 7.99436431e-01 3.09336105e-01]
#  [5.04508357e-01 8.63650615e-01 7.43254638e-01 3.19277116e-01]
#  [5.73561651e-01 8.53531285e-01 7.18763623e-01 3.35545769e-01]
#  [6.03579533e-01 8.39536631e-01 6.83016839e-01 3.54803006e-01]
#  [6.47174221e-01 8.35498168e-01 6.21501298e-01 3.51805912e-01]
#  [6.63861434e-01 8.20901753e-01 5.54067095e-01 3.63136949e-01]
#  [6.67945871e-01 8.06821421e-01 5.18254330e-01 3.62508789e-01]
#  [6.36820088e-01 8.09449412e-01 5.54748600e-01 3.70658198e-01]
#  [6.79740905e-01 8.22467176e-01 5.36042638e-01 3.71348848e-01]
#  [7.14832588e-01 8.16038886e-01 5.26939197e-01 3.91009663e-01]
#  [7.07381292e-01 7.95794282e-01 6.78742852e-01 4.20681936e-01]
#  [6.62647796e-01 7.71935385e-01 7.15283586e-01 4.21801041e-01]
#  [6.00515407e-01 7.32678654e-01 7.29441652e-01 4.17042314e-01]
#  [5.93312583e-01 6.96839450e-01 7.20567064e-01 4.34984461e-01]
#  [5.51464396e-01 6.62824369e-01 7.14381393e-01 4.64579777e-01]
#  [4.79025923e-01 6.39389912e-01 7.20146170e-01 4.70807538e-01]
#  [4.28340613e-01 6.12334642e-01 7.17403114e-01 4.66469336e-01]
#  [4.18749581e-01 5.89074136e-01 6.94271433e-01 4.64889089e-01]
#  [4.01411807e-01 5.58180498e-01 6.95638657e-01 4.48773567e-01]
#  [3.69672987e-01 5.58742671e-01 6.67466832e-01 4.39681370e-01]
#  [3.37788121e-01 5.55538854e-01 6.22462397e-01 4.19387611e-01]
#  [3.07887840e-01 5.73621466e-01 5.74108124e-01 4.20224835e-01]
#  [3.28750298e-01 5.80490269e-01 5.22278537e-01 4.21896190e-01]
#  [2.96445941e-01 5.75195573e-01 4.65160498e-01 4.11544464e-01]
#  [2.80130137e-01 5.83892940e-01 4.14340872e-01 3.90850230e-01]
#  [3.37814757e-01 5.96551602e-01 3.79875693e-01 3.91626444e-01]
#  [3.74051291e-01 6.30957475e-01 3.89773860e-01 4.11791107e-01]
#  [3.92524061e-01 6.40382452e-01 3.67771308e-01 4.05434670e-01]
#  [5.02791761e-01 6.62014585e-01 3.50774287e-01 3.99091285e-01]
#  [5.45301498e-01 6.71738968e-01 3.71252811e-01 3.88151261e-01]
#  [6.26121662e-01 6.84602064e-01 3.86365701e-01 3.77945160e-01]
#  [8.06657902e-01 6.84968736e-01 3.88943864e-01 3.64981493e-01]
#  [8.54471797e-01 6.84457389e-01 3.92682064e-01 3.49700896e-01]
#  [9.41672871e-01 6.81660639e-01 4.08525674e-01 3.60457129e-01]
#  [1.00000000e+00 6.76255262e-01 4.50719189e-01 3.74586979e-01]
#  [9.94978337e-01 6.82617716e-01 6.77509287e-01 3.70064890e-01]
#  [9.56925903e-01 6.75296992e-01 1.00000000e+00 3.59115809e-01]]
# [0.9569259  0.27792649 0.27743971 0.27764318 0.27791408 0.27768461
#  0.2776389  0.27759775 0.27749295 0.27785393 0.27726335 0.27722479
#  0.27712372 0.27749405 0.27781782 0.27767236 0.2776405  0.27736717
#  0.27756183 0.27715463 0.27723885 0.27733626 0.27769133 0.27798063
#  0.27787842 0.27744651 0.27755772 0.27782843 0.27816766 0.27751601
#  0.27728457 0.27821273 0.27773169 0.27710442 0.27753958 0.27773024
#  0.27747256]
# seed: 2
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# [[1.06961492e-01 5.79654627e-01 0.00000000e+00 1.88603304e-01]
#  [9.20376627e-02 3.60522337e-01 2.43250387e-02 4.45253200e-01]
#  [1.07409207e-01 2.61539286e-01 3.54364849e-02 5.62670527e-01]
#  [1.28339132e-01 1.71517624e-01 4.54877974e-02 6.71390631e-01]
#  [1.51503778e-01 1.05772599e-01 5.99691352e-02 7.68496081e-01]
#  [1.75047906e-01 4.53209285e-02 7.16949233e-02 8.62378480e-01]
#  [2.12044969e-01 1.90691205e-02 8.10480234e-02 9.47761767e-01]
#  [2.43290400e-01 3.28542921e-04 9.02613778e-02 9.82113036e-01]
#  [2.71410671e-01 0.00000000e+00 9.61111616e-02 9.89578142e-01]
#  [2.90727585e-01 3.87016464e-02 9.82398443e-02 1.00000000e+00]
#  [3.12981593e-01 7.99089519e-02 9.99598618e-02 9.92296274e-01]
#  [3.32396705e-01 1.28466488e-01 9.92274737e-02 9.47714763e-01]
#  [3.68731744e-01 1.86054888e-01 9.57284942e-02 8.74151083e-01]
#  [3.85730728e-01 2.58299971e-01 9.11733209e-02 7.95934607e-01]
#  [4.01263686e-01 3.28070245e-01 8.58640175e-02 6.99919448e-01]
#  [4.23665324e-01 3.98911771e-01 8.08162027e-02 6.10548378e-01]
#  [4.50166530e-01 4.68129673e-01 7.70740147e-02 5.07707403e-01]
#  [4.46839667e-01 5.35586280e-01 6.88996066e-02 4.24127396e-01]
#  [4.31559554e-01 6.02083998e-01 6.23569751e-02 3.46484844e-01]
#  [4.05570586e-01 6.53415581e-01 5.40306060e-02 2.61763627e-01]
#  [3.68788127e-01 7.02275853e-01 5.02957437e-02 1.93097802e-01]
#  [3.27964101e-01 7.33121035e-01 4.68755858e-02 1.28727011e-01]
#  [3.03421524e-01 7.52819396e-01 4.31201127e-02 9.70338391e-02]
#  [2.63231009e-01 7.67227621e-01 3.70195475e-02 5.57880565e-02]
#  [2.21147589e-01 7.74960464e-01 3.41335582e-02 1.74788336e-02]
#  [1.73664727e-01 7.71163018e-01 4.66808338e-02 3.11504684e-03]
#  [1.21893484e-01 7.60105610e-01 6.28776674e-02 0.00000000e+00]
#  [7.45386862e-02 7.43447147e-01 6.88562016e-02 1.36813612e-02]
#  [3.99392013e-02 7.11617042e-01 7.27526482e-02 3.44238555e-02]
#  [3.71737942e-02 6.75987815e-01 7.36284610e-02 8.05858943e-02]
#  [1.69539854e-02 6.37747430e-01 7.33488015e-02 1.44978169e-01]
#  [0.00000000e+00 5.99024747e-01 7.22905483e-02 1.91901290e-01]
#  [1.12170172e-02 5.51612135e-01 7.99598864e-02 2.39231265e-01]
#  [1.36955816e-02 5.08933668e-01 8.42481501e-02 3.10201340e-01]
#  [1.56581864e-02 4.66182896e-01 8.65351506e-02 3.82840380e-01]
#  [1.90393459e-02 4.37659029e-01 8.82775150e-02 4.44218833e-01]
#  [2.46571501e-02 4.15020722e-01 9.84981782e-02 4.94147959e-01]
#  [5.72005587e-02 3.89515169e-01 1.09722563e-01 5.30999794e-01]
#  [7.76955082e-02 3.75475774e-01 1.16875213e-01 5.57686195e-01]
#  [9.61753027e-02 3.79382124e-01 1.22053955e-01 5.95483423e-01]
#  [1.12952027e-01 3.96390297e-01 1.24467974e-01 6.07487872e-01]
#  [1.55170045e-01 4.16770991e-01 1.27851245e-01 6.29216762e-01]
#  [1.84374397e-01 4.67880437e-01 1.28592172e-01 6.45949238e-01]
#  [2.10491058e-01 5.00873616e-01 1.26863640e-01 6.37836545e-01]
#  [2.32237995e-01 5.40701792e-01 1.26746982e-01 6.12972103e-01]
#  [2.50453005e-01 5.83126640e-01 1.23175679e-01 6.04956279e-01]
#  [2.55422385e-01 6.13808842e-01 1.18136455e-01 5.98167886e-01]
#  [2.52857828e-01 6.35212469e-01 1.12792386e-01 5.64061003e-01]
#  [2.73036142e-01 6.82860531e-01 1.09995975e-01 5.25916001e-01]
#  [2.72476456e-01 7.40239215e-01 1.09516065e-01 4.76853253e-01]
#  [2.88612094e-01 7.99549739e-01 1.13864964e-01 4.38573299e-01]
#  [2.83517470e-01 8.53054180e-01 1.15735470e-01 3.94741642e-01]
#  [2.78579578e-01 8.92658472e-01 1.18467227e-01 3.45282844e-01]
#  [2.68329663e-01 9.48113429e-01 1.16908682e-01 3.21648573e-01]
#  [2.54511360e-01 9.75062911e-01 1.18570954e-01 3.03144751e-01]
#  [2.61888714e-01 9.88992049e-01 1.31045536e-01 2.74574783e-01]
#  [2.48961323e-01 1.00000000e+00 1.34907640e-01 2.63786281e-01]
#  [2.31859545e-01 9.91786143e-01 1.34885894e-01 2.43244046e-01]
#  [2.11763759e-01 9.79655892e-01 1.34537559e-01 2.54237417e-01]
#  [1.88258491e-01 9.50309745e-01 1.30014529e-01 2.48570123e-01]
#  [1.63717355e-01 9.16617128e-01 1.32289985e-01 2.46824235e-01]
#  [1.61511447e-01 8.83087280e-01 1.34250863e-01 2.42863710e-01]
#  [1.45604831e-01 8.40165556e-01 1.37640975e-01 2.49845879e-01]
#  [1.47683888e-01 8.19543628e-01 1.43260770e-01 2.66073408e-01]
#  [1.35399215e-01 7.84808403e-01 1.41889853e-01 2.74022535e-01]
#  [1.20942595e-01 7.70527009e-01 1.39542683e-01 3.09986402e-01]
#  [1.03772011e-01 7.63588948e-01 1.52035636e-01 3.60473402e-01]
#  [1.11113930e-01 7.41595586e-01 1.54149592e-01 3.78529512e-01]
#  [1.01825682e-01 7.10713566e-01 1.55862041e-01 3.92507722e-01]
#  [9.22488599e-02 6.80112921e-01 2.05868301e-01 4.29108671e-01]
#  [8.23599860e-02 6.55071391e-01 2.20044897e-01 4.64444630e-01]
#  [7.25207734e-02 6.40868936e-01 2.28795631e-01 4.95492703e-01]
#  [6.18045859e-02 6.51778992e-01 2.35141656e-01 5.01565719e-01]
#  [7.54785155e-02 6.49135705e-01 2.61413383e-01 5.03326044e-01]
#  [7.35648454e-02 6.56307273e-01 2.72630983e-01 5.06777808e-01]
#  [7.23560978e-02 7.25766234e-01 2.76905361e-01 5.07979109e-01]
#  [7.11131413e-02 7.55661004e-01 2.88384448e-01 4.94960523e-01]
#  [6.92469271e-02 7.74763236e-01 2.98237127e-01 4.97761810e-01]
#  [1.36361673e-01 7.83940035e-01 3.16778472e-01 4.98434260e-01]
#  [1.80959222e-01 8.05964502e-01 3.39835515e-01 4.82001470e-01]
#  [2.04358069e-01 8.32886781e-01 3.77460397e-01 4.64575733e-01]
#  [2.68285370e-01 8.46860666e-01 5.06301258e-01 4.54440609e-01]
#  [2.93932716e-01 8.72522566e-01 5.85579867e-01 4.56455097e-01]
#  [3.11828320e-01 8.92116849e-01 6.58440465e-01 4.44276218e-01]
#  [3.44081860e-01 9.03405942e-01 7.32648442e-01 4.15605323e-01]
#  [3.50305774e-01 9.05326777e-01 7.81992644e-01 3.96350292e-01]
#  [3.70870688e-01 9.06186729e-01 8.35829721e-01 3.79580902e-01]
#  [3.65687061e-01 9.00991115e-01 8.56908158e-01 3.55003148e-01]
#  [3.74503370e-01 8.86688559e-01 8.72491416e-01 3.32737189e-01]
#  [3.80230622e-01 9.01898361e-01 8.71733287e-01 3.32091604e-01]
#  [4.07409825e-01 9.01632750e-01 8.41179282e-01 3.34155705e-01]
#  [4.16744844e-01 8.94369324e-01 8.31399547e-01 3.22869857e-01]
#  [4.46707690e-01 8.80562785e-01 7.99436431e-01 3.09336105e-01]
#  [5.04508357e-01 8.63650615e-01 7.43254638e-01 3.19277116e-01]
#  [5.73561651e-01 8.53531285e-01 7.18763623e-01 3.35545769e-01]
#  [6.03579533e-01 8.39536631e-01 6.83016839e-01 3.54803006e-01]
#  [6.47174221e-01 8.35498168e-01 6.21501298e-01 3.51805912e-01]
#  [6.63861434e-01 8.20901753e-01 5.54067095e-01 3.63136949e-01]
#  [6.67945871e-01 8.06821421e-01 5.18254330e-01 3.62508789e-01]
#  [6.36820088e-01 8.09449412e-01 5.54748600e-01 3.70658198e-01]
#  [6.79740905e-01 8.22467176e-01 5.36042638e-01 3.71348848e-01]
#  [7.14832588e-01 8.16038886e-01 5.26939197e-01 3.91009663e-01]
#  [7.07381292e-01 7.95794282e-01 6.78742852e-01 4.20681936e-01]
#  [6.62647796e-01 7.71935385e-01 7.15283586e-01 4.21801041e-01]
#  [6.00515407e-01 7.32678654e-01 7.29441652e-01 4.17042314e-01]
#  [5.93312583e-01 6.96839450e-01 7.20567064e-01 4.34984461e-01]
#  [5.51464396e-01 6.62824369e-01 7.14381393e-01 4.64579777e-01]
#  [4.79025923e-01 6.39389912e-01 7.20146170e-01 4.70807538e-01]
#  [4.28340613e-01 6.12334642e-01 7.17403114e-01 4.66469336e-01]
#  [4.18749581e-01 5.89074136e-01 6.94271433e-01 4.64889089e-01]
#  [4.01411807e-01 5.58180498e-01 6.95638657e-01 4.48773567e-01]
#  [3.69672987e-01 5.58742671e-01 6.67466832e-01 4.39681370e-01]
#  [3.37788121e-01 5.55538854e-01 6.22462397e-01 4.19387611e-01]
#  [3.07887840e-01 5.73621466e-01 5.74108124e-01 4.20224835e-01]
#  [3.28750298e-01 5.80490269e-01 5.22278537e-01 4.21896190e-01]
#  [2.96445941e-01 5.75195573e-01 4.65160498e-01 4.11544464e-01]
#  [2.80130137e-01 5.83892940e-01 4.14340872e-01 3.90850230e-01]
#  [3.37814757e-01 5.96551602e-01 3.79875693e-01 3.91626444e-01]
#  [3.74051291e-01 6.30957475e-01 3.89773860e-01 4.11791107e-01]
#  [3.92524061e-01 6.40382452e-01 3.67771308e-01 4.05434670e-01]
#  [5.02791761e-01 6.62014585e-01 3.50774287e-01 3.99091285e-01]
#  [5.45301498e-01 6.71738968e-01 3.71252811e-01 3.88151261e-01]
#  [6.26121662e-01 6.84602064e-01 3.86365701e-01 3.77945160e-01]
#  [8.06657902e-01 6.84968736e-01 3.88943864e-01 3.64981493e-01]
#  [8.54471797e-01 6.84457389e-01 3.92682064e-01 3.49700896e-01]
#  [9.41672871e-01 6.81660639e-01 4.08525674e-01 3.60457129e-01]
#  [1.00000000e+00 6.76255262e-01 4.50719189e-01 3.74586979e-01]
#  [9.94978337e-01 6.82617716e-01 6.77509287e-01 3.70064890e-01]
#  [9.56925903e-01 6.75296992e-01 1.00000000e+00 3.59115809e-01]]
# [0.9569259  0.49648666 0.51029848 0.49375214 0.4684737  0.46969375
#  0.44796495 0.44303547 0.46974344 0.47302598 0.45845585 0.46631965
#  0.43549256 0.43891412 0.45943849 0.45208712 0.4267089  0.39388936
#  0.45883099 0.4545398  0.45109543 0.45614775 0.42802137 0.45794395
#  0.41057315 0.45108537 0.43178075 0.42484282 0.4617864  0.45731385
#  0.45975905 0.45569007 0.45237661 0.42875062 0.45747081 0.46603123
#  0.43422759]
# seed: 3
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
