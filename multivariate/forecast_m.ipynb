# %%
# access to content
# %cd /content

#  delete previous copy
# !rm -rf forecasting-cyber-threats

# new clone
# !git clone -v https://github.com/taasmaaawad-ops/forecasting-cyber-threats.git

# access to folder
# !ls forecasting-cyber-threats/
# Out:
# /content
# Cloning into 'forecasting-cyber-threats'...
# POST git-upload-pack (175 bytes)
# POST git-upload-pack (202 bytes)
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (344/344), done.
# remote: Compressing objects: 100% (341/341), done.
# remote: Total 344 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (344/344), 28.91 MiB | 16.47 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# multivariate  README.md  univariate

# %%
import csv
from pandas import read_csv
from matplotlib import pyplot as plt
import numpy as np
import os
import sys
import seaborn as sns
import pandas as pd
import math
from numpy import split
import random

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

from scipy.optimize import minimize
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import numpy
from tqdm import tqdm_notebook
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from numpy import array
#from itertools import product
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from tensorflow.keras import optimizers
from tensorflow import keras
import tensorflow as tf
from numpy.random import seed
from scipy import stats
from IPython.display import clear_output
import statistics
import keras.backend as K

plt.rcParams['savefig.dpi'] = 300

#for parsing the units, this function removes the comma and replaces it with dash to avoid splitting the units (as different hyperparameters) when building the hyperparameters list
def removeCommaInUnits(HP):
  units= HP[HP.index('['):HP.index(']')+1]
  if ',' in units:
    units = units.replace(',','-')
  HP=HP.replace(HP[HP.index('['):HP.index(']')+1],units)
  return HP

#this function puts back the comma in its place as it is needed while building our model
def putCommaInUnitsList(HP):
  return [i.replace('-',',') for i in HP]


def maximum(a, b):

    if a >= b:
        return a
    else:
        return b

def minimum(a, b):

    if a <= b:
        return a
    else:
        return b


def exponential_smoothing(series, alpha):

    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):

    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing - "+attack)
    plt.grid(True);

def double_exponential_smoothing(series, alpha, beta):

    result = [series[0]]
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):

    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing - "+attack)
    plt.grid(True)
    plt.show()


#stationarity test
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):

    if not isinstance(y, pd.Series):
        y = pd.Series(y)

    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))

        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title(attack_title+' - Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        plt.show()


# convert history into inputs and outputs
def to_supervised(train, n_input, n_out=1):
    # flatten data
    data = train #modified

    X, y = list(), list()
    in_start = 0
    # step over the entire history one time step at a time
    for _ in range(len(data)):
        # define the end of the input sequence
        in_end = in_start + n_input
        out_end = in_end + n_out
        # ensure we have enough data for this instance
        if out_end <= len(data):
            X.append(data[in_start:in_end, :])
            y.append(data[in_end:out_end, :])
        # move along one time step
        in_start += 1
    return array(X), array(y)

#Bayesian LSTM

# class BayesianLSTM(LSTM): #inherits LSTM but set training=True which keeps dropout on during test time.
#   def call(self, inputs):
#     return super().call(inputs, training=True)


class BayesianLSTM(tf.keras.layers.Layer):
    def __init__(self, units, return_sequences=False, recurrent_dropout=0.0, **kwargs):
        super().__init__()
        self.units = units
        self.return_sequences = return_sequences
        self.recurrent_dropout = recurrent_dropout

        self.lstm = tf.keras.layers.LSTM(
            units,
            return_sequences=return_sequences,
            **kwargs
        )
        self.dropout_layer = tf.keras.layers.Dropout(recurrent_dropout)

    def call(self, inputs, training=None):
        x = self.dropout_layer(inputs, training=True)
        return self.lstm(x, training=True)

    def build(self, input_shape):
        self.lstm.build(input_shape)
        self.built = True




# train the model using Bayesian LSTM
def build_model(train, test, n_input, layer, unit, epoch, lr,rdo,n_features):

    # prepare data
    train_x, train_y = to_supervised(train, n_input)
    test_x, test_y=to_supervised(test,n_input)


    # define parameters
    verbose, epochs, batch_size = 0,epoch, 8


    model = Sequential()


    if layer==1:
        model.add(BayesianLSTM(unit[0], input_shape=(n_input, n_features),recurrent_dropout=rdo, activation = keras.layers.LeakyReLU(alpha=0.2)))
        model.add(RepeatVector(1))
        model.add(BayesianLSTM(unit[0], activation = keras.layers.LeakyReLU(alpha=0.2), return_sequences=True, recurrent_dropout=rdo))
        model.add(TimeDistributed(Dense(100, activation = keras.layers.LeakyReLU(alpha=0.2))))
        model.add(TimeDistributed(Dense(n_features)))
    elif layer==2:
        model.add(BayesianLSTM(unit[0], activation = keras.layers.LeakyReLU(alpha=0.2), input_shape=(n_input, n_features),return_sequences=True,recurrent_dropout=rdo))
        model.add(BayesianLSTM(unit[1], activation = keras.layers.LeakyReLU(alpha=0.2) ,recurrent_dropout=rdo))
        model.add(RepeatVector(1))
        model.add(BayesianLSTM(unit[1], activation = keras.layers.LeakyReLU(alpha=0.2), return_sequences=True,recurrent_dropout=rdo))
        model.add(BayesianLSTM(unit[0], activation = keras.layers.LeakyReLU(alpha=0.2), return_sequences=True,recurrent_dropout=rdo))
        model.add(TimeDistributed(Dense(100, activation = keras.layers.LeakyReLU(alpha=0.2))))
        model.add(TimeDistributed(Dense(n_features)))

    opt = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=opt, loss='mse', metrics=['mape']) #compile the model with mean square error as the loss function

    #if the loss does not improve after 30 epochs, stop anyway (early stopping)
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

    # fit network
    train_history= model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(test_x, test_y),verbose=verbose,callbacks=[es])

    loss = train_history.history['loss']
    val_loss = train_history.history['val_loss']

    return model


#forecasts the future trend of a single attack 3 years in advance
def forecast(data, e_data, smoothed, model, min_list,seed, attack_label):

    #get best model's hyperparameters
    n_input=min_list[2]
    layer=min_list[3]
    unit=min_list[4]
    lr=min_list[5]
    epoch=min_list[6]
    rdo=min_list[7]
    n_features=min_list[9]

    #build the model using the best hyperparameters using the whole data
    model = build_model(e_data, e_data, n_input, layer, unit, epoch, lr,rdo,n_features)

    #Bayesian LSTM performs multiple iterations to create a prediction distribution (i.e., mean and variance)
    n_iterations=10
    predictions_2d=list()
    for r in range(0,n_iterations):

      predictions = list()
      predictions.append(e_data[-1,]) #for plotting purpose
      #look back in test data
      history=e_data[-n_input:,]

      for i in range(36): #predicts 36 months using sliding-window
        f_hat=model.predict(history.reshape(1,history.shape[0],history.shape[1]))
        history=numpy.append(history, f_hat[0][0])
        history=history.reshape(-1,n_features)
        history=history[1:,]#move the sliding window 1 step
        predictions.append(f_hat[0][0])
      predictions_2d.append(predictions)


    predictions_2d = array(predictions_2d)
    predictions_mean=numpy.mean(predictions_2d,axis=0)#mean
    predictions_var=numpy.var(predictions_2d,axis=0)#variance
    std_predictions=numpy.std(predictions_2d,axis=0)#standard deviation
    z=1.96
    confidence_95=z*std_predictions/math.sqrt(len(predictions_mean))# 95% confidence interval

    #get only first feature (ground truth prediction)
    data= data[:,0]
    predictions_mean=predictions_mean[:,0]
    confidence_95=confidence_95[:,0]
    predictions_var=predictions_var[:,0]

    #calculate the height of data on the plot (plot range) to disable variance/95% conf.interval plot if too large or too small.
    upper=maximum(numpy.amax(predictions_mean),numpy.amax(data))
    lower=minimum(numpy.amin(predictions_mean),numpy.amin(data))
    p_range=upper-lower
    var_plot=True
    max_var=0
    for v in predictions_var:
      if v>p_range:
        var_plot=False
      if v>max_var:
        max_var=v
    if max_var*30<p_range:
      var_plot=False

    conf_plot=True
    max_conf=0
    for conf in confidence_95:
      if conf>p_range:
        conf_plot=False
      if conf>max_conf:
        max_conf=conf
    if max_conf*30<p_range:
      conf_plot=False


    print(e_data)
    print(predictions_mean)

    #Plot the forecast
    x=['2012', '2013','2014', '2015', '2016', '2017', '2018','2019', '2020', '2021','2022','2023','2024','2025']
    pyplot.plot(range(len(data)),data,'--', color="blue",label='Data')
    pyplot.plot(range(len(data), len(data)+len(predictions_mean)),predictions_mean,'--', color="red",label='Prediction')
    if conf_plot:
      pyplot.fill_between(range(len(data), len(data)+len(predictions_mean)),(predictions_mean.reshape(-1)- (confidence_95.reshape(-1))), (predictions_mean.reshape(-1)+confidence_95.reshape(-1)), color='green', alpha=0.2,label='95% Confidence')
    if var_plot:
      pyplot.fill_between(range(len(data), len(data)+len(predictions_mean)),(predictions_mean.reshape(-1)- (predictions_var.reshape(-1))), (predictions_mean.reshape(-1)+predictions_var.reshape(-1)), color='green', alpha=0.1,label='Variance')
    plt.xticks([6,18,30,42,54,66,78,90,102,114,126,138,150,162], x) # positions of years on x axis
    plt.ylabel("No of incidents",fontsize=15)
    plt.yticks(fontsize=13)
    plt.legend(loc="best",prop={'size': 11})
    plt.axis('tight')
    plt.grid(True)
    pyplot.xticks(rotation=90,fontsize=13)
    pyplot.title(attack_label+' (M)', y=1.03,fontsize=18)

    #save the forecast plot to file
    images_dir = '/content/forecasting-cyber-threats/multivariate/output_forecast/'
    plt.savefig(f"{images_dir}/"+attack_label.replace('/','_')+str(seed)+".png",bbox_inches = "tight")#the name of the file includes the seed
    pyplot.show()

    #write the data and forecast
    data=data.ravel().tolist()
    predictions_mean=predictions_mean.tolist()

    files_dir = '/content/forecasting-cyber-threats/multivariate/output_forecast/'
    with open(files_dir+attack_title.replace('/','_')+'_data_'+str(seed)+'.txt', 'w') as f: #the name of the file includes the seed
      f.write('Data: '+str(data))
      f.write('\nPredictions: '+str(predictions_mean))
      data.extend(predictions_mean)
      f.write('\nData and Predictions: '+str(data))
      f.write('\n95_Confidence: '+str(confidence_95.tolist()))
      f.write('\nVariance: '+str(predictions_var.tolist()))
      f.close()



#read input data
data = read_csv('/content/forecasting-cyber-threats/multivariate/input_data/T-HMGDN-F-0711-0322.csv', header=0)
attacks=data.columns.values.tolist()
raw_values = data.values
avg_data=0
scaler = MinMaxScaler(feature_range=(0, 1))

#name of attack columns (in the dataset) to be forecasted. "All" refers to the number of attacks in all countries combined
attacks=['Phishing-ALL', 'Password Attack-ALL', 'SQL Injection-ALL',
         'Defacement-ALL', 'Trojan-ALL', 'Vulnerability-ALL', 'Advanced persistent threat-ALL',
         'XSS-ALL', 'Data Breach-ALL', 'Disinformation/Misinformation-ALL', 'Targeted Attack-ALL','Adware-ALL',
         'Malvertising-ALL', 'Backdoor-ALL', 'Cryptojacking-ALL','Worms-ALL', 'Spyware-ALL',  'Mentions-DNS Spoofing',
         'Mentions-WannaCry Ransomware','Mentions-Wiper', 'Mentions-Pharming', 'Mentions-Insider Threat',
         'Mentions-Drive-by', 'Mentions-Rootkit', 'Mentions-Data Poisoning', 'Mentions-Keylogger', 'Mentions-DNS Tunneling',
         'Mentions-Session Hijacking','Mentions-URL manipulation']

done=[] #can be manually appended with already forecasted attacks to avoid repeating the process



#iterate over all attacks to forecast their trend
for attack in attacks:
  if attack in done:
    continue
  clear_output()

  if not 'ALL' in attack and not 'Mentions' in attack:
    continue;
  if 'Mentions-' in attack:
    attack_title=attack[attack.index('-')+1:]
  else:
    attack_title=attack[0:attack.rindex('-')]


  if len(attack_title)>18:
    attack_title=attack_title.rsplit(' ', 1)[0]



  # get the optimal model hyperparameters from file
  files_dir = '/content/forecasting-cyber-threats/multivariate/output_hyperparameters/'
  with open(f"{files_dir}/"+attack_title.replace('/','_')+'.txt') as f:
      lines = f.readlines()
      f.close()
  HP_str= lines[1]
  HP_str=HP_str[HP_str.index('[')+1:-1]
  HP_str=removeCommaInUnits(HP_str)
  HP=HP_str.split(', ')
  HP=putCommaInUnitsList(HP)
  print('HP:',HP)


  min_mape=999999999
  min_list=[]
  model=None
  c=1

  best_data=[]
  n_features=2 #number of features by default (Hackmageddon ground truth + 1 more)
  features=[1,2,3,4] # 1- attack mentions 2- Armed Conflict Areas/Wars 3- Holidays 4- Mix of all features. Ground truth Hackmageddon is always there as the first feature.

  #get smoothing constants
  alpha=float(HP[0])
  beta=float(HP[1])

  #get feature combination number
  feature=int(HP[10])
  print('features=',feature)

  #number of features is 2 unless the number of combination is the 4th, the case in which all features combined.
  if feature==4:
    n_features=4 #update the number of features since all features combined

  #building attack title for plots
  rest=attack[:-4]
  if 'Mentions-' in attack:
   rest=attack[9:]

  featureList=[] #to be used as the input data to the model later

  #if alpha and beta <1 then the method is double exponential smoothing
  # if alpha<1 and beta = 1, the method is exponential smoothing
  # if both beta and alpha equal 1, then no smoothing

  #Double Exponential Smoothing
  if not alpha==1 and not beta==1:
    smoothed=double_exponential_smoothing(data[attack], alpha,beta)
    smoothed=smoothed[0:-1]  #remove the one future step forecast from des
    plt.plot(data[attack], label = "Actual")
    plt.plot(smoothed, label="Alpha {}, beta {}".format(alpha, beta),color="red")
    plt.title("Double Exponential Smoothing - "+attack_title)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.grid(True)
    plt.xlabel("Month")
    if 'Mentions-' in attack:
     plt.ylabel("No of mentions")
    else:
     plt.ylabel("No of incidents")
    plt.show() #plot the data and smoothed data
    avg_data=sum(smoothed)/len(smoothed)
    featureList.append(smoothed)

    #smooth and plot the other features if included in this random selection
    #1- attack mentions 2- Armed Conflict Areas/Wars 3- Holidays 4- Mix of all features. Ground truth Hackmageddon is always there as the first feature.
    if feature==1 or feature==4:
        smoothed_v=double_exponential_smoothing(data['Mentions-'+rest], alpha,beta)
        smoothed_v=smoothed_v[0:-1] #thanks for the one additional forecast but no thanks,
        plt.plot(data['Mentions-'+rest], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}, beta {}".format(alpha, beta),color="red")
        plt.title("Double Exponential Smoothing - "+'Mentions of '+rest)
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)

    if feature==2 or feature==4:
        smoothed_v=double_exponential_smoothing(data['WAR/CONFLICT ALL'], alpha,beta)
        smoothed_v=smoothed_v[0:-1] #remove the one future step forecast from des
        plt.plot(data['WAR/CONFLICT ALL'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}, beta {}".format(alpha, beta),color="red")
        plt.title("Double Exponential Smoothing - "+'WAR/CONFLICT')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)

    if feature==3 or feature==4:
        smoothed_v=double_exponential_smoothing(data['Holidays'], alpha,beta)
        smoothed_v=smoothed_v[0:-1] #remove the one future step forecast from des
        plt.plot(data['Holidays'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}, beta {}".format(alpha, beta),color="red")
        plt.title("Double Exponential Smoothing - "+'Holidays')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of holidays")
        plt.show()
        featureList.append(smoothed_v)


  #exponential smoothing
  elif beta==1 and not alpha==1:
    smoothed=exponential_smoothing(data[attack], alpha)
    plt.plot(data[attack], label = "Actual")
    plt.plot(smoothed, label="Alpha {}".format(alpha),color="red")
    plt.title("Exponential Smoothing - "+attack_title)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.grid(True)
    plt.xlabel("Month")
    if 'Mentions-' in attack:
        plt.ylabel("No of mentions")
    else:
        plt.ylabel("No of incidents")
    plt.show()
    avg_data=sum(smoothed)/len(smoothed)
    featureList.append(smoothed)

    if feature==1 or feature==4:
        smoothed_v=exponential_smoothing(data['Mentions-'+rest], alpha)
        plt.plot(data['Mentions-'+rest], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}".format(alpha),color="red")
        plt.title("Exponential Smoothing - "+'Mentions of '+rest)
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)

    if feature==2 or feature==4:
        smoothed_v=exponential_smoothing(data['WAR/CONFLICT ALL'], alpha)
        plt.plot(data['WAR/CONFLICT ALL'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}".format(alpha),color="red")
        plt.title("Exponential Smoothing - "+'WAR/CONFLICT')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of mentions")
        plt.show()
        featureList.append(smoothed_v)
    if feature==3 or feature==4:
        smoothed_v=exponential_smoothing(data['Holidays'], alpha)
        plt.plot(data['Holidays'], label = "Actual")
        plt.plot(smoothed_v, label="Alpha {}".format(alpha),color="red")
        plt.title("Exponential Smoothing - "+'Holidays')
        plt.legend(loc="best")
        plt.axis('tight')
        plt.grid(True)
        plt.xlabel("Month")
        plt.ylabel("No of holidays")
        plt.show()
        featureList.append(smoothed_v)


  #no smoothing
  elif alpha==1 and beta==1:
    smoothed=data[attack]
    avg_data=smoothed.mean()
    featureList.append(smoothed)
    if feature==1 or feature==4:
        smoothed_v=data['Mentions-'+rest]
        featureList.append(smoothed_v)
    if feature==2 or feature==4:
        smoothed_v=data['WAR/CONFLICT ALL']
        featureList.append(smoothed_v)
    if feature==3 or feature==4:
        smoothed_v=data['Holidays']
        featureList.append(smoothed_v)



  #stationarity test
  tsplot(smoothed, lags=30)


  smoothed_all=numpy.array([smoothed]).reshape(-1,1)

  ##################################normalization##############################################
  featureList=numpy.transpose(featureList)
  prepared_data=numpy.array(featureList).reshape(-1,n_features)
  scaled_data = scaler.fit_transform(prepared_data)
  print('data shape=',scaled_data.shape)
  ##################################normalization##############################################

  #cut first part of the data if it is zeros (look for emerging index of the attack)
  e_index=0 #emerging index
  for i in range(len(scaled_data[:,0])-2):
    if scaled_data[i,0]>0 and scaled_data[i+1,0]>0 and scaled_data[i+2,0]>0:
        e_index=i
        break
  print('Emerging Index=',e_index)
  scaled_e_data=scaled_data[e_index:]
  print('Length of data after cut=',len(scaled_e_data))

  #Get model hyperparameters:
  lag=int(HP[2])#lookback period
  lr=float(HP[5])#learning rate
  epoch=int(HP[6])# epochs
  unit=list(map(int, HP[4].replace('[','').replace(']','').split(', '))) #units
  layer=len(unit) #layers
  rdo=float(HP[7]) #recurrent dropout
  diff_label='not differenced' #no differencing

  #build the set of hyperparameters based on the optimised model
  hp_set=[alpha, beta,lag,layer, unit, lr, epoch,rdo,diff_label,n_features, feature]
  print('Hyperparameters:',hp_set)

  #forecast the attack's future trend using 3 seeds 1-3
  for a in range(1,4):
   print('seed:',a)
   seed(a)
   tf.random.set_seed(a)
   forecast(scaled_data,scaled_e_data,smoothed_all, model,hp_set,a, attack_title)
# Out:
# HP: ['0.05', '1', '5', '1', '[200]', '0.0006', '30', '0.4', "'not differenced'", '2', '2', '1']
# features= 2
# data shape= (129, 2)
# Emerging Index= 3
# Length of data after cut= 126
# Hyperparameters: [0.05, 1.0, 5, 1, [200], 0.0006, 30, 0.4, 'not differenced', 2, 2]
# seed: 1
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [[6.01618281e-04 2.41687484e-03]
#  [5.71537367e-04 7.76107388e-03]
#  [5.42960499e-04 1.06381736e-02]
#  [1.71904904e-03 1.25674698e-02]
#  [1.63309658e-03 1.57530122e-02]
#  [1.55144175e-03 1.74004350e-02]
#  [1.47386967e-03 1.79144176e-02]
#  [1.40017618e-03 2.01777108e-02]
#  [1.93178566e-03 2.18736021e-02]
#  [1.83519637e-03 2.28717364e-02]
#  [1.74343655e-03 2.45432596e-02]
#  [2.25788301e-03 2.66238347e-02]
#  [2.14498886e-03 2.94824016e-02]
#  [2.03773941e-03 3.33752503e-02]
#  [2.53747072e-03 3.34266536e-02]
#  [2.41059719e-03 3.54847126e-02]
#  [2.29006733e-03 3.59577903e-02]
#  [2.17556396e-03 4.00175620e-02]
#  [2.66840404e-03 4.28742488e-02]
#  [3.13660212e-03 4.44360547e-02]
#  [3.58139030e-03 4.36285819e-02]
#  [3.40232078e-03 4.54233424e-02]
#  [3.83382303e-03 5.78158464e-02]
#  [3.64213187e-03 6.79701822e-02]
#  [3.46002528e-03 6.68560868e-02]
#  [2.55469004e-02 6.53257152e-02]
#  [2.42695554e-02 6.29166088e-02]
#  [2.30560776e-02 6.13706099e-02]
#  [2.19032737e-02 6.05700399e-02]
#  [2.14097283e-02 6.72534416e-02]
#  [2.09408602e-02 6.94548541e-02]
#  [1.98938172e-02 7.01238008e-02]
#  [1.88991263e-02 7.09967425e-02]
#  [1.79541700e-02 7.87373482e-02]
#  [1.70564615e-02 8.51521235e-02]
#  [1.62036384e-02 8.72302892e-02]
#  [3.76533329e-02 8.84457638e-02]
#  [3.57706663e-02 8.86245642e-02]
#  [3.39821329e-02 9.09720537e-02]
#  [3.22830263e-02 9.19075279e-02]
#  [3.06688750e-02 9.20845469e-02]
#  [2.91354312e-02 9.47481167e-02]
#  [2.76786597e-02 9.50153867e-02]
#  [2.68963450e-02 9.52008995e-02]
#  [2.55515277e-02 9.60197793e-02]
#  [4.65338277e-02 9.91572973e-02]
#  [4.42071363e-02 1.03375155e-01]
#  [4.25983978e-02 1.10062379e-01]
#  [4.04684779e-02 1.12822637e-01]
#  [3.84450540e-02 1.15784915e-01]
#  [3.65228013e-02 1.15050995e-01]
#  [3.52982795e-02 1.17681511e-01]
#  [5.63948602e-02 1.27978027e-01]
#  [7.64366119e-02 1.28553346e-01]
#  [7.32163996e-02 1.26999052e-01]
#  [6.95555796e-02 1.26800660e-01]
#  [6.60778006e-02 1.24465529e-01]
#  [6.27739106e-02 1.28914571e-01]
#  [6.14400699e-02 1.32058476e-01]
#  [5.89696847e-02 1.35751706e-01]
#  [5.60212005e-02 1.40416515e-01]
#  [7.54800168e-02 1.38864603e-01]
#  [7.17060160e-02 1.38070353e-01]
#  [6.81207152e-02 1.49443758e-01]
#  [6.47146794e-02 1.49408093e-01]
#  [6.14789455e-02 1.50124929e-01]
#  [5.90066165e-02 1.87686574e-01]
#  [7.83161620e-02 1.85280014e-01]
#  [9.72618486e-02 1.82352108e-01]
#  [9.30003745e-02 1.81478200e-01]
#  [1.11813469e-01 1.98542616e-01]
#  [1.73002424e-01 2.00558249e-01]
#  [1.64953922e-01 1.99918015e-01]
#  [1.78966102e-01 2.08237428e-01]
#  [2.14537550e-01 2.15359181e-01]
#  [2.26070548e-01 2.29574598e-01]
#  [2.59286774e-01 2.45151378e-01]
#  [2.69183930e-01 2.69456365e-01]
#  [3.22504362e-01 3.56977150e-01]
#  [3.73158774e-01 3.79545091e-01]
#  [3.77362330e-01 3.97831750e-01]
#  [4.25875461e-01 4.20822359e-01]
#  [4.04581687e-01 4.28362705e-01]
#  [4.07214098e-01 4.49425438e-01]
#  [4.31373146e-01 4.51335225e-01]
#  [4.34470838e-01 4.62214268e-01]
#  [4.35608791e-01 4.69974271e-01]
#  [4.36088228e-01 4.65140905e-01]
#  [5.03323322e-01 4.89267136e-01]
#  [5.24481763e-01 4.97481444e-01]
#  [5.00062530e-01 4.93447122e-01]
#  [5.20180775e-01 5.22078612e-01]
#  [5.18236467e-01 5.36807972e-01]
#  [5.59705891e-01 5.31257689e-01]
#  [6.43621597e-01 5.26757576e-01]
#  [6.14448608e-01 5.49019542e-01]
#  [6.75172157e-01 6.16443837e-01]
#  [6.85933302e-01 6.16039415e-01]
#  [6.73896513e-01 6.23638564e-01]
#  [6.84721440e-01 7.48804283e-01]
#  [6.74550099e-01 7.40589144e-01]
#  [7.08203842e-01 7.24100053e-01]
#  [7.39573279e-01 7.02374510e-01]
#  [7.47715986e-01 6.96308584e-01]
#  [7.77109816e-01 7.05981959e-01]
#  [7.61717438e-01 7.09552736e-01]
#  [7.45891443e-01 7.00366665e-01]
#  [7.31458365e-01 7.16435513e-01]
#  [7.18348560e-01 7.06834328e-01]
#  [7.72072256e-01 6.90744790e-01]
#  [8.23109767e-01 6.79634647e-01]
#  [8.49335526e-01 6.70051395e-01]
#  [8.74249997e-01 6.58676764e-01]
#  [8.97918745e-01 6.53506246e-01]
#  [8.98144179e-01 6.58333580e-01]
#  [9.42276475e-01 6.89300154e-01]
#  [9.41487259e-01 6.79131681e-01]
#  [9.38932649e-01 6.72011554e-01]
#  [9.38310624e-01 6.90761506e-01]
#  [9.59979577e-01 6.93487021e-01]
#  [9.34842093e-01 6.82036199e-01]
#  [9.10359864e-01 6.72737424e-01]
#  [8.66045108e-01 6.73157706e-01]
#  [9.11782358e-01 6.90518285e-01]
#  [9.57639219e-01 8.37397595e-01]
#  [1.00000000e+00 1.00000000e+00]]
# [1.         0.86772123 0.90159424 0.91748134 0.88321866 0.89778029
#  0.85450752 0.87935576 0.8302931  0.87321897 0.88066486 0.8573101
#  0.82455282 0.78971679 0.79375933 0.78440032 0.79919555 0.80340014
#  0.79280154 0.78778698 0.81949597 0.79777157 0.79985453 0.81073893
#  0.7911399  0.80786203 0.76687433 0.79979648 0.77820321 0.7277723
#  0.76757075 0.80373428 0.832486   0.82892115 0.80715249 0.80971647
#  0.80735165]
# seed: 2
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 907ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [[6.01618281e-04 2.41687484e-03]
#  [5.71537367e-04 7.76107388e-03]
#  [5.42960499e-04 1.06381736e-02]
#  [1.71904904e-03 1.25674698e-02]
#  [1.63309658e-03 1.57530122e-02]
#  [1.55144175e-03 1.74004350e-02]
#  [1.47386967e-03 1.79144176e-02]
#  [1.40017618e-03 2.01777108e-02]
#  [1.93178566e-03 2.18736021e-02]
#  [1.83519637e-03 2.28717364e-02]
#  [1.74343655e-03 2.45432596e-02]
#  [2.25788301e-03 2.66238347e-02]
#  [2.14498886e-03 2.94824016e-02]
#  [2.03773941e-03 3.33752503e-02]
#  [2.53747072e-03 3.34266536e-02]
#  [2.41059719e-03 3.54847126e-02]
#  [2.29006733e-03 3.59577903e-02]
#  [2.17556396e-03 4.00175620e-02]
#  [2.66840404e-03 4.28742488e-02]
#  [3.13660212e-03 4.44360547e-02]
#  [3.58139030e-03 4.36285819e-02]
#  [3.40232078e-03 4.54233424e-02]
#  [3.83382303e-03 5.78158464e-02]
#  [3.64213187e-03 6.79701822e-02]
#  [3.46002528e-03 6.68560868e-02]
#  [2.55469004e-02 6.53257152e-02]
#  [2.42695554e-02 6.29166088e-02]
#  [2.30560776e-02 6.13706099e-02]
#  [2.19032737e-02 6.05700399e-02]
#  [2.14097283e-02 6.72534416e-02]
#  [2.09408602e-02 6.94548541e-02]
#  [1.98938172e-02 7.01238008e-02]
#  [1.88991263e-02 7.09967425e-02]
#  [1.79541700e-02 7.87373482e-02]
#  [1.70564615e-02 8.51521235e-02]
#  [1.62036384e-02 8.72302892e-02]
#  [3.76533329e-02 8.84457638e-02]
#  [3.57706663e-02 8.86245642e-02]
#  [3.39821329e-02 9.09720537e-02]
#  [3.22830263e-02 9.19075279e-02]
#  [3.06688750e-02 9.20845469e-02]
#  [2.91354312e-02 9.47481167e-02]
#  [2.76786597e-02 9.50153867e-02]
#  [2.68963450e-02 9.52008995e-02]
#  [2.55515277e-02 9.60197793e-02]
#  [4.65338277e-02 9.91572973e-02]
#  [4.42071363e-02 1.03375155e-01]
#  [4.25983978e-02 1.10062379e-01]
#  [4.04684779e-02 1.12822637e-01]
#  [3.84450540e-02 1.15784915e-01]
#  [3.65228013e-02 1.15050995e-01]
#  [3.52982795e-02 1.17681511e-01]
#  [5.63948602e-02 1.27978027e-01]
#  [7.64366119e-02 1.28553346e-01]
#  [7.32163996e-02 1.26999052e-01]
#  [6.95555796e-02 1.26800660e-01]
#  [6.60778006e-02 1.24465529e-01]
#  [6.27739106e-02 1.28914571e-01]
#  [6.14400699e-02 1.32058476e-01]
#  [5.89696847e-02 1.35751706e-01]
#  [5.60212005e-02 1.40416515e-01]
#  [7.54800168e-02 1.38864603e-01]
#  [7.17060160e-02 1.38070353e-01]
#  [6.81207152e-02 1.49443758e-01]
#  [6.47146794e-02 1.49408093e-01]
#  [6.14789455e-02 1.50124929e-01]
#  [5.90066165e-02 1.87686574e-01]
#  [7.83161620e-02 1.85280014e-01]
#  [9.72618486e-02 1.82352108e-01]
#  [9.30003745e-02 1.81478200e-01]
#  [1.11813469e-01 1.98542616e-01]
#  [1.73002424e-01 2.00558249e-01]
#  [1.64953922e-01 1.99918015e-01]
#  [1.78966102e-01 2.08237428e-01]
#  [2.14537550e-01 2.15359181e-01]
#  [2.26070548e-01 2.29574598e-01]
#  [2.59286774e-01 2.45151378e-01]
#  [2.69183930e-01 2.69456365e-01]
#  [3.22504362e-01 3.56977150e-01]
#  [3.73158774e-01 3.79545091e-01]
#  [3.77362330e-01 3.97831750e-01]
#  [4.25875461e-01 4.20822359e-01]
#  [4.04581687e-01 4.28362705e-01]
#  [4.07214098e-01 4.49425438e-01]
#  [4.31373146e-01 4.51335225e-01]
#  [4.34470838e-01 4.62214268e-01]
#  [4.35608791e-01 4.69974271e-01]
#  [4.36088228e-01 4.65140905e-01]
#  [5.03323322e-01 4.89267136e-01]
#  [5.24481763e-01 4.97481444e-01]
#  [5.00062530e-01 4.93447122e-01]
#  [5.20180775e-01 5.22078612e-01]
#  [5.18236467e-01 5.36807972e-01]
#  [5.59705891e-01 5.31257689e-01]
#  [6.43621597e-01 5.26757576e-01]
#  [6.14448608e-01 5.49019542e-01]
#  [6.75172157e-01 6.16443837e-01]
#  [6.85933302e-01 6.16039415e-01]
#  [6.73896513e-01 6.23638564e-01]
#  [6.84721440e-01 7.48804283e-01]
#  [6.74550099e-01 7.40589144e-01]
#  [7.08203842e-01 7.24100053e-01]
#  [7.39573279e-01 7.02374510e-01]
#  [7.47715986e-01 6.96308584e-01]
#  [7.77109816e-01 7.05981959e-01]
#  [7.61717438e-01 7.09552736e-01]
#  [7.45891443e-01 7.00366665e-01]
#  [7.31458365e-01 7.16435513e-01]
#  [7.18348560e-01 7.06834328e-01]
#  [7.72072256e-01 6.90744790e-01]
#  [8.23109767e-01 6.79634647e-01]
#  [8.49335526e-01 6.70051395e-01]
#  [8.74249997e-01 6.58676764e-01]
#  [8.97918745e-01 6.53506246e-01]
#  [8.98144179e-01 6.58333580e-01]
#  [9.42276475e-01 6.89300154e-01]
#  [9.41487259e-01 6.79131681e-01]
#  [9.38932649e-01 6.72011554e-01]
#  [9.38310624e-01 6.90761506e-01]
#  [9.59979577e-01 6.93487021e-01]
#  [9.34842093e-01 6.82036199e-01]
#  [9.10359864e-01 6.72737424e-01]
#  [8.66045108e-01 6.73157706e-01]
#  [9.11782358e-01 6.90518285e-01]
#  [9.57639219e-01 8.37397595e-01]
#  [1.00000000e+00 1.00000000e+00]]
# [1.         0.89685074 0.89114012 0.90708214 0.95947335 0.97394069
#  0.9099622  0.86134917 0.93088323 0.8693427  0.84979762 0.88552657
#  0.92124656 0.8869283  0.83478274 0.85216094 0.86665791 0.87223817
#  0.82937245 0.86427083 0.864302   0.83586619 0.82283869 0.85344641
#  0.81108271 0.84518339 0.83874301 0.81213624 0.81128591 0.84067205
#  0.85472637 0.83581042 0.81438425 0.8155439  0.82122363 0.81165326
#  0.81692852]
# seed: 3
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
